# %% [markdown]
# ## Tanishq Keswani
# ### Practical 5

# %% [markdown]
# #### AIM- Named Entity Recognition and Dependency Parsing for Information Extration using spacy. Consider any text file (research article technical blog , any unstructured corpus used before) Perform NER to extract entities from individual sentences using spacy. Use Dependency parsing, POS tagging to extract relationships between the entities. Create a tuple for information extraction T1( Entity1, Entity2, Relation label), Display no of such tuples extracted from considered corpus as extracted information

# %% [markdown]
# When to use Spacy:
#
# sent,word tokenization, lemmatization, pos tagging, entity recognition, dependency parsing

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Life is gift from god. do your best") #pass text file

# %%
for sent in doc.sents:  #separate sentences
    print(sent)
# Out:
# Life is gift from god.
# do your best

# %%
for word in doc:
    print(word.text, word.tag_,word.pos_,word.dep_)
    
spacy.explain('pobj')
spacy.explain('dobj')
# Out:
# Life NN NOUN nsubj
# is VBZ AUX ROOT
# gift NN NOUN attr
# from IN ADP prep
# god NNP PROPN pobj
# . . PUNCT punct
# do VB VERB ROOT
# your PRP$ PRON poss
# best JJS ADJ dobj
# 'direct object'

# %% [markdown]
# life label is NN, pos tag is Noun
# is is labelled as VBZ, pos is Aux...

# %%
doc.text.split()  #divide text into list
# Out:
# ['Life', 'is', 'gift', 'from', 'god.', 'do', 'your', 'best']

# %% [markdown]
# lemmatization

# %%
exa = "runs running ran"

# %%
nlp_exa = nlp(exa)

# %%
[word.lemma_ for word in nlp_exa]
# Out:
# ['run', 'run', 'run']

# %%
exa1 = "knows knowing known no"

# %%
nlp_exa1 = nlp(exa1)

# %%
[word.lemma_ for word in nlp_exa1]
# Out:
# ['know', 'know', 'known', 'no']

# %% [markdown]
# named entity recognition

# %%
kalam = "APJ Abdul Kalam is a famous name in the whole world. He is counted among the greatest scientists of the 21st century. Even more, he becomes the 11th president of India and served his country. He was the most valued person of the country as his contribution as a scientist and as a president is beyond compare."

# %%
nlp_kalam = nlp(kalam)
[(l,l.label_,l.label) for l in nlp_kalam.ents]
# Out:
# [(APJ Abdul Kalam, 'PERSON', 380),
#  (the 21st century, 'DATE', 391),
#  (11th, 'ORDINAL', 396),
#  (India, 'GPE', 384)]

# %%
from spacy import displacy
doc = nlp("APJ Abdul Kalam is a famous name in the whole world. He is counted among the greatest scientists of the 21st century. Even more, he becomes the 11th president of India and served his country. He was the most valued person of the country as his contribution as a scientist and as a president is beyond compare.")

# %%
displacy.render(nlp_kalam,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APJ Abdul Kalam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a famous name in the whole world. He is counted among the greatest scientists of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 21st century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Even more, he becomes the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11th
# ...

# %% [markdown]
# dependency parsing (discourse analysis)

# %%
from spacy import displacy
doc = nlp("India is my country. It is secular.")
displacy.render(doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="78ffd60d5d244d07b1325c8b38e784b2-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# ### Named Entity Recognition

# %%
import nltk
from nltk.corpus import brown
nltk.corpus.brown.fileids()
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44',
#  'cb01',
#  'cb02',
#  'cb03',
#  'cb04',
#  'cb05',
#  'cb06',
#  'cb07',
#  'cb08',
#  'cb09',
#  'cb10',
#  'cb11',
#  'cb12',
#  'cb13',
#  'cb14',
#  'cb15',
#  'cb16',
#  'cb17',
#  'cb18',
#  'cb19',
#  'cb20',
#  'cb21',
#  'cb22',
#  'cb23',
#  'cb24',
#  'cb25',
#  'cb26',
#  'cb27',
#  'cc01',
#  'cc02',
#  'cc03',
#  'cc04',
#  'cc05',
#  'cc06',
#  'cc07',
#  'cc08',
#  'cc09',
#  'cc10',
#  'cc11',
#  'cc12',
#  'cc13',
#  'cc14',
#  'cc15',
#  'cc16',
#  'cc17',
#  'cd01',
#  'cd02',
# ...

# %%
cr = nltk.corpus.brown.raw('cr07')
cr
# Out:
# "\n\n\tOne/cd day/nn ,/, the/at children/nns had/hvd wanted/vbn to/to get/vb up/rp onto/in General/nn-tl Burnside's/np$ horse/nn ./.\nThey/ppss wanted/vbd to/to see/vb what/wdt his/pp$ back/nn felt/vbd like/cs --/-- the/at General's/nn$-tl ./.\nHe/pps looked/vbd so/ql comfortable/jj being/beg straight/rb ./.\nThey/ppss wanted/vbd to/to touch/vb the/at mystery/nn ./.\nArlene/np was/bedz boosting/vbg them/ppo up/rp when/wrb the/at policeman/nn came/vbd by/rb ./.\n\n\n\tHe/pps was/bedz very/ql rude/jj ./.\n\n\n\tArlene/np had/hvd a/at hard/jj voice/nn ,/, too/rb ,/, this/dt time/nn ./.\nThe/at policeman's/nn$ eyes/nns rather/ql popped/vbd for/in a/at second/nn ;/. ;/.\nbut/cc then/jj Arlene/np got/vbd another/dt tone/nn in/in a/at hurry/nn ,/, and/cc she/pps said/vbd ,/, ``/`` If/cs it/pps wasn't/bedz* for/in these/dts dear/jj children/nns ''/'' --/-- ./.\n\n\n\tThe/at policeman/nn got/vbd a/at confused/vbn ,/, funny/jj look/nn on/in his/pp$ face/nn ,/, and/cc he/pps had/hvd answered/vb
# ...

# %%
nlp_cr = nlp(cr)  #using spacy
[(l,l.label_,l.label) for l in nlp_cr.ents]
# Out:
# [(One/cd day, 'DATE', 391),
#  (Arlene, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (second, 'ORDINAL', 396),
#  (Arlene, 'PERSON', 380),
#  (pps, 'ORG', 383),
#  (Arlene, 'PERSON', 380),
#  (two, 'CARDINAL', 397),
#  (Arlene, 'PERSON', 380),
#  (pp$, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (What/wdt is/bez, 'WORK_OF_ART', 388),
#  (Arlene, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (British, 'NORP', 381),
#  (First, 'ORDINAL', 396),
#  (Arlene, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (One, 'CARDINAL', 397),
#  (pp$, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (Burnside, 'GPE', 384),
#  (Arlene, 'PERSON', 380),
#  (Imagine, 'WORK_OF_ART', 388),
#  (Arlene, 'PERSON', 380),
#  (Arlene, 'PERSON', 380),
#  (Burnside, 'GPE', 384),
#  (first, 'ORDINAL', 396),
#  (ben, 'PERSON', 380),
#  (Burnside, 'GPE', 384),
#  (pp$ feet, 'MONEY', 394),
#  (Burnside, 'GPE', 384),
#  (Burnside, 'GPE', 384),
#  (Arlene, 'PERSON', 380),
# ...

# %%
displacy.render(nlp_cr,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One/cd day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# /nn ,/, the/at children/nns had/hvd wanted/vbn to/to get/vb up/rp onto/in General/nn-tl Burnside's/np$ horse/nn ./.</br>They/ppss wanted/vbd to/to see/vb what/wdt his/pp$ back/nn felt/vbd like/cs --/-- the/at General's/nn$-tl ./.</br>He/pps looked/vbd so/ql comfortable/jj being/beg straight/rb ./.</br>They/ppss wanted/vbd to/to touch/vb the/at mystery/nn ./.</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arlene
# ...

# %%
import nltk

# %%
sentence = "WASHINGTON -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch, the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement."

# %%
for sent in nltk.sent_tokenize(sentence):
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE WASHINGTON
# GPE New York
# PERSON Loretta E. Lynch
# GPE Brooklyn

# %%
#information extraction -> extract keywords -> summarized document
import spacy
from spacy.matcher import Matcher 

from spacy import displacy 


# load english language model
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])
